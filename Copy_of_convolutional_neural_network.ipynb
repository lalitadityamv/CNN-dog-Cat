# %% [markdown]
# # Convolutional Neural Network

# %% [markdown]
# ### Importing the libraries

# %%
import tensorflow as tf

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
tf.__version__
# Out:
# '2.18.0'

# %% [markdown]
# ## Part 1 - Data Preprocessing

# %% [markdown]
# ### Preprocessing the Training set

# %%
train_datagen=ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)
training_set=train_datagen.flow_from_directory(
    'training_set',
    target_size=(64,64),
    batch_size=32,
    class_mode='binary'
)
# Out:
# Found 8000 images belonging to 2 classes.

# %% [markdown]
# ### Preprocessing the Test set

# %%
test_datagen=ImageDataGenerator(rescale=1./255)
test_set=test_datagen.flow_from_directory(
    'test_set',
    target_size=(64,64),
    batch_size=32,
    class_mode='binary'
)
# Out:
# Found 2000 images belonging to 2 classes.

# %% [markdown]
# ## Part 2 - Building the CNN

# %% [markdown]
# ### Initialising the CNN

# %%
cnn=tf.keras.models.Sequential()

# %% [markdown]
# ### Step 1 - Convolution

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32,kernel_size=3,activation='relu',input_shape=[64,64,3]))

# %% [markdown]
# ### Step 2 - Pooling

# %%
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2,strides=2))

# %% [markdown]
# ### Adding a second convolutional layer

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32,kernel_size=3,activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2,strides=2))

# %% [markdown]
# ### Step 3 - Flattening

# %%
cnn.add(tf.keras.layers.Flatten())

# %% [markdown]
# ### Step 4 - Full Connection

# %%
cnn.add(tf.keras.layers.Dense(units=128,activation='relu'))

# %% [markdown]
# ### Step 5 - Output Layer

# %%
cnn.add(tf.keras.layers.Dense(units=1,activation='sigmoid'))

# %% [markdown]
# ## Part 3 - Training the CNN

# %% [markdown]
# ### Compiling the CNN

# %%
cnn.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %% [markdown]
# ### Training the CNN on the Training set and evaluating it on the Test set

# %%
cnn.fit(x=training_set,validation_data=test_set,epochs=25)
# Out:
# Epoch 1/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 50s 191ms/step - accuracy: 0.5326 - loss: 0.6954 - val_accuracy: 0.6195 - val_loss: 0.6428
# Epoch 2/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 50s 199ms/step - accuracy: 0.6411 - loss: 0.6363 - val_accuracy: 0.7065 - val_loss: 0.5786
# Epoch 3/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 42s 169ms/step - accuracy: 0.6867 - loss: 0.5926 - val_accuracy: 0.6440 - val_loss: 0.6623
# Epoch 4/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 45s 180ms/step - accuracy: 0.7086 - loss: 0.5643 - val_accuracy: 0.7250 - val_loss: 0.5448
# Epoch 5/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 64s 255ms/step - accuracy: 0.7400 - loss: 0.5168 - val_accuracy: 0.6970 - val_loss: 0.6155
# Epoch 6/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 58s 231ms/step - accuracy: 0.7452 - loss: 0.5008 - val_accuracy: 0.7640 - val_loss: 0.4950
# Epoch 7/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 49s 198ms/step - accuracy: 0.7684 - loss: 0.4784 - val_accuracy: 0.7705 - val_loss: 0.4996
# Epoch 8/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 60s 240ms/step - accuracy: 0.7685 - loss: 0.4794 - val_accuracy: 0.7325 - val_loss: 0.5610
# Epoch 9/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 50s 198ms/step - accuracy: 0.7766 - loss: 0.4632 - val_accuracy: 0.7790 - val_loss: 0.4853
# Epoch 10/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 49s 197ms/step - accuracy: 0.8032 - loss: 0.4331 - val_accuracy: 0.7770 - val_loss: 0.4700
# Epoch 11/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 48s 191ms/step - accuracy: 0.8011 - loss: 0.4212 - val_accuracy: 0.7755 - val_loss: 0.4807
# Epoch 12/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 47s 188ms/step - accuracy: 0.8010 - loss: 0.4202 - val_accuracy: 0.7830 - val_loss: 0.4760
# Epoch 13/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 54s 216ms/step - accuracy: 0.8151 - loss: 0.3969 - val_accuracy: 0.7850 - val_loss: 0.4623
# Epoch 14/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 59s 235ms/step - accuracy: 0.8264 - loss: 0.3904 - val_accuracy: 0.7760 - val_loss: 0.5027
# Epoch 15/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 54s 216ms/step - accuracy: 0.8210 - loss: 0.3833 - val_accuracy: 0.7950 - val_loss: 0.4744
# Epoch 16/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 58s 234ms/step - accuracy: 0.8365 - loss: 0.3594 - val_accuracy: 0.8080 - val_loss: 0.4476
# Epoch 17/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 51s 203ms/step - accuracy: 0.8462 - loss: 0.3502 - val_accuracy: 0.7900 - val_loss: 0.4938
# Epoch 18/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 48s 192ms/step - accuracy: 0.8544 - loss: 0.3388 - val_accuracy: 0.8025 - val_loss: 0.4754
# Epoch 19/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 45s 182ms/step - accuracy: 0.8578 - loss: 0.3272 - val_accuracy: 0.7540 - val_loss: 0.5810
# Epoch 20/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 42s 168ms/step - accuracy: 0.8545 - loss: 0.3285 - val_accuracy: 0.7750 - val_loss: 0.5357
# Epoch 21/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 42s 169ms/step - accuracy: 0.8676 - loss: 0.3012 - val_accuracy: 0.7975 - val_loss: 0.5182
# Epoch 22/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 41s 164ms/step - accuracy: 0.8753 - loss: 0.2858 - val_accuracy: 0.7865 - val_loss: 0.5082
# Epoch 23/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 48s 190ms/step - accuracy: 0.8797 - loss: 0.2854 - val_accuracy: 0.7935 - val_loss: 0.4994
# Epoch 24/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 56s 224ms/step - accuracy: 0.8930 - loss: 0.2542 - val_accuracy: 0.7950 - val_loss: 0.4925
# Epoch 25/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 55s 220ms/step - accuracy: 0.8882 - loss: 0.2566 - val_accuracy: 0.8050 - val_loss: 0.5309

# %% [markdown]
# ## Part 4 - Making a single prediction

# %%
import numpy as np

# %%
from tensorflow.keras.preprocessing import image

# %%
test_image=image.load_img('01Larson-Bats-new.jpg',target_size=(64,64))
test_image=image.img_to_array(test_image)
test_image=np.expand_dims(test_image,axis=0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[190], line 1
# ----> 1 test_image=image.load_img('01Larson-Bats-new.jpg',target_size=(64,64))
#       2 test_image=image.img_to_array(test_image)
#       3 test_image=np.expand_dims(test_image,axis=0)
#
# File ~\anaconda3\Lib\site-packages\keras\src\utils\image_utils.py:235, in load_img(path, color_mode, target_size, interpolation, keep_aspect_ratio)
#     233     if isinstance(path, pathlib.Path):
#     234         path = str(path.resolve())
# --> 235     with open(path, "rb") as f:
#     236         img = pil_image.open(io.BytesIO(f.read()))
#     237 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '01Larson-Bats-new.jpg'

# %%
result=cnn.predict(test_image)
training_set.class_indices
prediciton=''
if result[0][0]==1:
  prediction='dog'
else:
  prediction='cat'
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step

# %%
print(prediction)
# Out:
# dog
